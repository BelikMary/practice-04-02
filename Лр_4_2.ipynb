# %% [markdown]
# <a href="https://colab.research.google.com/github/BelikMary/practice-04-02/blob/main/%D0%9B%D1%80_4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6fa3d22d-7406-430c-9a56-0d93240b952a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fa3d22d-7406-430c-9a56-0d93240b952a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_excel("data-6322-2022-10-07.xlsx")

# %%
df1
# Out:
#        ID                                           FullName         INN  \
# 0      41  Государственное бюджетное общеобразовательное ...  7701375995
# 1      42  Государственное бюджетное общеобразовательное ...  7708071876
# 2      43  Государственное бюджетное общеобразовательное ...  7704118139
# 3      44  Государственное бюджетное общеобразовательное ...  7720325492
# 4      45  Общеобразовательная автономная некоммерческая ...  7727282640
# ..    ...                                                ...         ...
# 888  1714  Автономная некоммерческая организация професси...  9729237205
# 889  1715  федеральное государственное бюджетное общеобра...  7727020771
# 890  1716  Государственное бюджетное общеобразовательное ...  7725143915
# 891  1717  Государственное автономное профессиональное об...  7719286023
# 892  1718  Общеобразовательная Автономная Некоммерческая ...  9715203260
#
#               OGRN                         AccreditationAuthority  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      893 non-null    int64
#  1   FullName                893 non-null    object
#  2   INN                     893 non-null    int64
#  3   OGRN                    893 non-null    int64
#  4   AccreditationAuthority  893 non-null    object
#  5   Education               893 non-null    object
#  6   CertificateNumber       893 non-null    int64
#  7   CertificateIssueDate    893 non-null    object
#  8   Validity                893 non-null    object
#  9   CertificateFormSeries   893 non-null    object
#  10  CertificateFormNumber   893 non-null    int64
#  11  global_id               893 non-null    int64
# dtypes: int64(6), object(6)
# memory usage: 83.8+ KB

# %%
df2=df1.set_index('ID')
df2
# Out:
#                                                FullName         INN  \
# ID
# 41    Государственное бюджетное общеобразовательное ...  7701375995
# 42    Государственное бюджетное общеобразовательное ...  7708071876
# 43    Государственное бюджетное общеобразовательное ...  7704118139
# 44    Государственное бюджетное общеобразовательное ...  7720325492
# 45    Общеобразовательная автономная некоммерческая ...  7727282640
# ...                                                 ...         ...
# 1714  Автономная некоммерческая организация професси...  9729237205
# 1715  федеральное государственное бюджетное общеобра...  7727020771
# 1716  Государственное бюджетное общеобразовательное ...  7725143915
# 1717  Государственное автономное профессиональное об...  7719286023
# 1718  Общеобразовательная Автономная Некоммерческая ...  9715203260
#
#                OGRN                         AccreditationAuthority  \
# ID
# 41    5137746011035  Департамент образования и науки города Москвы
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 893 entries, 41 to 1718
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   FullName                893 non-null    object
#  1   INN                     893 non-null    int64
#  2   OGRN                    893 non-null    int64
#  3   AccreditationAuthority  893 non-null    object
#  4   Education               893 non-null    object
#  5   CertificateNumber       893 non-null    int64
#  6   CertificateIssueDate    893 non-null    object
#  7   Validity                893 non-null    object
#  8   CertificateFormSeries   893 non-null    object
#  9   CertificateFormNumber   893 non-null    int64
#  10  global_id               893 non-null    int64
# dtypes: int64(5), object(6)
# memory usage: 83.7+ KB

# %%
 # !pip install PyMySQL
 # !pip install mysql-connector-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 43 kB 2.2 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 23.5 MB 1.5 MB/s
# ...

# %%
import sqlalchemy
database_username = 'MGPU_ADEU_101'
database_password = '24037427'
database_ip       = '95.131.149.21'
database_name     = 'mgpu_adeu_101'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.format(database_username, database_password, database_ip, database_name))
df2.to_sql(con=database_connection, name='lr_04_02_education', if_exists='replace',index=False)
